# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# فروش شکلات
# </font>
# </h1>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در این گام از پروژه قصد داریم برای شکلات‌ها با توجه به برخی مشخصات‌شان و تحقیق‌هایی که کرده‌ایم قیمت تعیین کنیم. برای این کار از داده‌هایی که در گام قبل پردازش کرده‌ایم استفاده کرده و سپس مرحله به مرحله سعی می‌کنیم تخمین قیمت خود را بهتر کنیم.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در گام پیشین پروژه یک سری پیش‌پردازش‌هایی روی مجموعه‌داده‌ی شکلات‌ها انجام داده و حاصل را در فایل <code>chocolate_preprocessed.csv</code> ذخیره کردید. بنابراین ابتدا در سلول زیر این فایل را به شکل یک دیتافریم بخوانید.
# </font>
# </p>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/ML/DataMining')

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ML/DataMining/گام اول: محموله ی بزرگ/chocolate_preprocessed.csv')
df
# Out:
#        Company Specific Bean Origin  Review Date  Cocoa Percent  \
# 0     A. Morin          Agua Grande         2016           63.0
# 1     A. Morin                Kpime         2015           70.0
# 2     A. Morin               Atsane         2015           70.0
# 3     A. Morin                Akata         2015           70.0
# 4     A. Morin               Quilla         2015           70.0
# ...        ...                  ...          ...            ...
# 1790    Zotter                 Peru         2011           70.0
# 1791    Zotter                Congo         2011           65.0
# 1792    Zotter         Kerala State         2011           65.0
# 1793    Zotter         Kerala State         2011           62.0
# 1794    Zotter   Brazil, Mitzi Blue         2010           65.0
#
#      Company Location  Rating  Bean Type Broad Bean Origin
# 0              France    3.75      Blend          Sao Tome
# 1              France    2.75      Blend              Togo
# 2              France    3.00      Blend              Togo
# 3              France    3.50      Blend              Togo
# 4              France    3.50      Blend              Peru
# ...               ...     ...        ...               ...
# 1790          Austria    3.75      Blend              Peru
# 1791          Austria    3.00  Forastero             Congo
# 1792          Austria    3.50  Forastero             India
# 1793          Austria    3.25      Blend             India
# 1794          Austria    3.00      Blend            Brazil
#
# [1795 rows x 8 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت اول
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# فرض کنید که بعد از کمی تحقیق متوجه شده‌ایم که قیمت یک شکلات با درصد امتیاز آن توسط متخصصان رابطه‌ی مستقیم دارد. خوشبختانه این امتیاز در مشخصات داده‌های ما وجود دارد، اما مسئله این است که این امتیازها به‌صورت درصد نیستند. پس در این مرحله از شما می‌خواهیم تا مقادیر ستون <code>Rating</code> را به گونه‌ای تغییر مقیاس دهید که بالاترین مقدار آن ۱۰۰ باشد و سایر مقادیر نیز دقیقاً به همان نسبت تغییر کنند. به‌عنوان مثال فرض کنید بیشترین مقداری که در این ستون وجود دارد برابر ۴ باشد. در این‌صورت برای تبدیل ۴ به ۱۰۰ باید آن را ضرب در ۲۵ کنید. پس تمام مقادیر این ستون باید ضرب در ۲۵ شوند. توجه داشته باشید که در نهایت نوع ستون شما باید <code>float</code> باشد.
# </font>
# </p>

# %%
df['Rating'].max()
# Out:
# 5.0

# %%
df['Rating'] = df['Rating'].apply(lambda row: row * 20)

df.head()
# Out:
#     Company Specific Bean Origin  Review Date  Cocoa Percent Company Location  \
# 0  A. Morin          Agua Grande         2016           63.0           France
# 1  A. Morin                Kpime         2015           70.0           France
# 2  A. Morin               Atsane         2015           70.0           France
# 3  A. Morin                Akata         2015           70.0           France
# 4  A. Morin               Quilla         2015           70.0           France
#
#    Rating Bean Type Broad Bean Origin
# 0    75.0     Blend          Sao Tome
# 1    55.0     Blend              Togo
# 2    60.0     Blend              Togo
# 3    70.0     Blend              Togo
# 4    70.0     Blend              Peru

# %%
df['Rating'].max()
# Out:
# 100.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1795 non-null   object
#  1   Specific Bean Origin  1795 non-null   object
#  2   Review Date           1795 non-null   int64
#  3   Cocoa Percent         1795 non-null   float64
#  4   Company Location      1795 non-null   object
#  5   Rating                1795 non-null   float64
#  6   Bean Type             1795 non-null   object
#  7   Broad Bean Origin     1794 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 112.3+ KB

# %%
df['Rating'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت دوم
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# بعد از کمی تحقیق مشخص شد که قیمت ۱۰۰ گرم کاکائوی خالص با بالاترین کیفیت ۲۵۰۰۰۰ تومان است. بنابراین می‌توانیم با ضرب درصد کاکائو (ستون <code>Cocoa Percent</code>) در قیمت صد گرم آن (عدد ۲۵) و همچنین درصد امتیاز (ستون <code>Rating</code>)،‌ قیمت صد گرم از یک نوع شکلات را تخمین بزنیم.
# در این قسمت به کمک فرمول زیر قیمت صد گرم از  هر نوع شکلات را محاسبه کرده و در ستون جدیدی به نام <code>price(100g)</code> ذخیره کنید.
# <br>
# <center>
# قیمت صد گرم = درصد کاکائو × امتیاز × ۲۵
# </center>
# </font>
# </p>

# %%
df['price(100g)'] = 25 * df['Rating'] *df['Cocoa Percent']
df
# Out:
#        Company Specific Bean Origin  Review Date  Cocoa Percent  \
# 0     A. Morin          Agua Grande         2016           63.0
# 1     A. Morin                Kpime         2015           70.0
# 2     A. Morin               Atsane         2015           70.0
# 3     A. Morin                Akata         2015           70.0
# 4     A. Morin               Quilla         2015           70.0
# ...        ...                  ...          ...            ...
# 1790    Zotter                 Peru         2011           70.0
# 1791    Zotter                Congo         2011           65.0
# 1792    Zotter         Kerala State         2011           65.0
# 1793    Zotter         Kerala State         2011           62.0
# 1794    Zotter   Brazil, Mitzi Blue         2010           65.0
#
#      Company Location  Rating  Bean Type Broad Bean Origin  price(100g)
# 0              France    75.0      Blend          Sao Tome     118125.0
# 1              France    55.0      Blend              Togo      96250.0
# 2              France    60.0      Blend              Togo     105000.0
# 3              France    70.0      Blend              Togo     122500.0
# 4              France    70.0      Blend              Peru     122500.0
# ...               ...     ...        ...               ...          ...
# 1790          Austria    75.0      Blend              Peru     131250.0
# 1791          Austria    60.0  Forastero             Congo      97500.0
# 1792          Austria    70.0  Forastero             India     113750.0
# 1793          Austria    65.0      Blend             India     100750.0
# 1794          Austria    60.0      Blend            Brazil      97500.0
#
# [1795 rows x 9 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت سوم
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# فرض کنید که متوجه شده‌ایم شکلات‌های تلخ گران‌تر و پرسودتر هستند. بنابراین قصد داریم ادامه‌ی تمرین را تنها با این نوع از شکلات‌ها پیش ببریم.
# در این قسمت شکلات‌هایی که درصد کاکائو آن‌ها بیشتر از ۷۰ درصد است را به‌عنوان شکلات تلخ در نظر گرفته و در مجموعه‌داده‌ی جدیدی با نام <code>dark_chocolates</code> ذخیره کنید.
# </font>
# </p>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# <span style="color:green"><b>راهنمایی:</b></span>
# بعد از جداسازی و ساخت دیتافریم، به کمک تابع <code dir=ltr>reset_index()</code> نمایه‌ها را ریست کنید. در این مرحله به آرگومان‌های <code>inplace</code> و <code>drop</code> هم توجه کنید.
# </font>
# </p>

# %%
# Filter rows where Cocoa Percent is greater than 70
dark_chocolates = df[df['Cocoa Percent'] > 70]
dark_chocolates
# Out:
#                  Company                      Specific Bean Origin  \
# 26                   Adi                        Vanua Levu, Toto-A
# 27                   Adi                                Vanua Levu
# 28                   Adi                    Vanua Levu, Ami-Ami-CA
# 32    Akesson's (Pralus)  Bali (west), Sukrama Family, Melaya area
# 33    Akesson's (Pralus)               Madagascar, Ambolikapiky P.
# ...                  ...                                       ...
# 1778              Zotter                                       Raw
# 1779              Zotter              Bocas del Toro, Cocabo Co-op
# 1784              Zotter                                    El Oro
# 1785              Zotter                              Huiwani Coop
# 1786              Zotter                             El Ceibo Coop
#
#       Review Date  Cocoa Percent Company Location  Rating  \
# 26           2011           80.0             Fiji    65.0
# 27           2011           88.0             Fiji    70.0
# 28           2011           72.0             Fiji    70.0
# 32           2011           75.0      Switzerland    75.0
# 33           2010           75.0      Switzerland    55.0
# ...           ...            ...              ...     ...
# 1778         2014           80.0          Austria    55.0
# 1779         2012           72.0          Austria    70.0
# 1784         2012           75.0          Austria    60.0
# 1785         2012           75.0          Austria    60.0
# 1786         2012           90.0          Austria    65.0
#
#                  Bean Type Broad Bean Origin  price(100g)
# 26              Trinitario              Fiji     130000.0
# 27              Trinitario              Fiji     154000.0
# 28              Trinitario              Fiji     126000.0
# 32              Trinitario         Indonesia     140625.0
# 33                 Criollo        Madagascar     103125.0
# ...                    ...               ...          ...
# 1778                 Blend             Other     110000.0
# 1779                 Blend            Panama     126000.0
# 1784  Forastero (Nacional)           Ecuador     112500.0
# 1785   Criollo, Trinitario  Papua New Guinea     112500.0
# 1786                 Blend           Bolivia     146250.0
#
# [795 rows x 9 columns]

# %%
dark_chocolates.reset_index(drop=True, inplace=True)
dark_chocolates
# Out:
#                 Company                      Specific Bean Origin  \
# 0                   Adi                        Vanua Levu, Toto-A
# 1                   Adi                                Vanua Levu
# 2                   Adi                    Vanua Levu, Ami-Ami-CA
# 3    Akesson's (Pralus)  Bali (west), Sukrama Family, Melaya area
# 4    Akesson's (Pralus)               Madagascar, Ambolikapiky P.
# ..                  ...                                       ...
# 790              Zotter                                       Raw
# 791              Zotter              Bocas del Toro, Cocabo Co-op
# 792              Zotter                                    El Oro
# 793              Zotter                              Huiwani Coop
# 794              Zotter                             El Ceibo Coop
#
#      Review Date  Cocoa Percent Company Location  Rating  \
# 0           2011           80.0             Fiji    65.0
# 1           2011           88.0             Fiji    70.0
# 2           2011           72.0             Fiji    70.0
# 3           2011           75.0      Switzerland    75.0
# 4           2010           75.0      Switzerland    55.0
# ..           ...            ...              ...     ...
# 790         2014           80.0          Austria    55.0
# 791         2012           72.0          Austria    70.0
# 792         2012           75.0          Austria    60.0
# 793         2012           75.0          Austria    60.0
# 794         2012           90.0          Austria    65.0
#
#                 Bean Type Broad Bean Origin  price(100g)
# 0              Trinitario              Fiji     130000.0
# 1              Trinitario              Fiji     154000.0
# 2              Trinitario              Fiji     126000.0
# 3              Trinitario         Indonesia     140625.0
# 4                 Criollo        Madagascar     103125.0
# ..                    ...               ...          ...
# 790                 Blend             Other     110000.0
# 791                 Blend            Panama     126000.0
# 792  Forastero (Nacional)           Ecuador     112500.0
# 793   Criollo, Trinitario  Papua New Guinea     112500.0
# 794                 Blend           Bolivia     146250.0
#
# [795 rows x 9 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت چهارم
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# نوع دانه‌ی استفاده شده برای ساخت شکلات نیز در مرغوبیت آن تاثیر مستقیم می‌گذارد. برای مثال یکی از بهترین دانه‌های شکلات از نوع <code>Trinitario</code> است.
# به همین دلیل تصمیم گرفته‌ایم قیمت شکلات‌های تلخی (دیتافریم <code>dark_chocolates</code>) که از این دانه استفاده کرده‌اند را ۱۰ درصد افزایش دهیم.
# <br>
# ابتدا در متغیر <code>has_Trinitario</code> برای هر شکلات مشخص کنید که آیا در نام دانه‌های مختلف این شکلات (ستون <code>Bean Type</code>) اسمی از <code>Trinitario</code> برده شده است یا خیر. یعنی خروجی شما باید به شکل یک آرایه به طول دیتافریم شکلات‌های تلخ باشد که با توجه به وجود یا عدم وجود این نوع دانه در آن شکلات مقدار <code>True</code> یا <code>False</code> داشته باشد.
# </font>
# </p>

# %%
has_Trinitario = dark_chocolates['Bean Type'].str.contains('Trinitario')
has_Trinitario
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 790    False
# 791    False
# 792    False
# 793     True
# 794    False
# Name: Bean Type, Length: 795, dtype: bool

# %%
dark_chocolates['has_Trinitario'] = has_Trinitario
dark_chocolates
# Out:
# /tmp/ipython-input-849601614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dark_chocolates['has_Trinitario'] = has_Trinitario
#                 Company                      Specific Bean Origin  \
# 0                   Adi                        Vanua Levu, Toto-A
# 1                   Adi                                Vanua Levu
# 2                   Adi                    Vanua Levu, Ami-Ami-CA
# 3    Akesson's (Pralus)  Bali (west), Sukrama Family, Melaya area
# 4    Akesson's (Pralus)               Madagascar, Ambolikapiky P.
# ..                  ...                                       ...
# 790              Zotter                                       Raw
# 791              Zotter              Bocas del Toro, Cocabo Co-op
# 792              Zotter                                    El Oro
# 793              Zotter                              Huiwani Coop
# 794              Zotter                             El Ceibo Coop
#
#      Review Date  Cocoa Percent Company Location  Rating  \
# 0           2011           80.0             Fiji    65.0
# 1           2011           88.0             Fiji    70.0
# 2           2011           72.0             Fiji    70.0
# 3           2011           75.0      Switzerland    75.0
# 4           2010           75.0      Switzerland    55.0
# ..           ...            ...              ...     ...
# 790         2014           80.0          Austria    55.0
# 791         2012           72.0          Austria    70.0
# 792         2012           75.0          Austria    60.0
# 793         2012           75.0          Austria    60.0
# 794         2012           90.0          Austria    65.0
#
#                 Bean Type Broad Bean Origin  price(100g)  has_Trinitario
# 0              Trinitario              Fiji     130000.0            True
# 1              Trinitario              Fiji     154000.0            True
# 2              Trinitario              Fiji     126000.0            True
# 3              Trinitario         Indonesia     140625.0            True
# 4                 Criollo        Madagascar     103125.0           False
# ..                    ...               ...          ...             ...
# 790                 Blend             Other     110000.0           False
# 791                 Blend            Panama     126000.0           False
# 792  Forastero (Nacional)           Ecuador     112500.0           False
# 793   Criollo, Trinitario  Papua New Guinea     112500.0            True
# 794                 Blend           Bolivia     146250.0           False
#
# [795 rows x 10 columns]

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# اکنون می‌توانید از آرایه‌ی <code>has_Trinitario</code> استفاده کرده و قیمت آن ردیف‌هایی که در این آرایه مقدار <code>True</code> دارند را ۱۰ درصد افزایش دهید.
# </font>
# </p>

# %%
mask = dark_chocolates['has_Trinitario'] == True
dark_chocolates.loc[mask, 'price(100g)'] *= 1.1
dark_chocolates
# Out:
#                 Company                      Specific Bean Origin  \
# 0                   Adi                        Vanua Levu, Toto-A
# 1                   Adi                                Vanua Levu
# 2                   Adi                    Vanua Levu, Ami-Ami-CA
# 3    Akesson's (Pralus)  Bali (west), Sukrama Family, Melaya area
# 4    Akesson's (Pralus)               Madagascar, Ambolikapiky P.
# ..                  ...                                       ...
# 790              Zotter                                       Raw
# 791              Zotter              Bocas del Toro, Cocabo Co-op
# 792              Zotter                                    El Oro
# 793              Zotter                              Huiwani Coop
# 794              Zotter                             El Ceibo Coop
#
#      Review Date  Cocoa Percent Company Location  Rating  \
# 0           2011           80.0             Fiji    65.0
# 1           2011           88.0             Fiji    70.0
# 2           2011           72.0             Fiji    70.0
# 3           2011           75.0      Switzerland    75.0
# 4           2010           75.0      Switzerland    55.0
# ..           ...            ...              ...     ...
# 790         2014           80.0          Austria    55.0
# 791         2012           72.0          Austria    70.0
# 792         2012           75.0          Austria    60.0
# 793         2012           75.0          Austria    60.0
# 794         2012           90.0          Austria    65.0
#
#                 Bean Type Broad Bean Origin  price(100g)  has_Trinitario
# 0              Trinitario              Fiji     143000.0            True
# 1              Trinitario              Fiji     169400.0            True
# 2              Trinitario              Fiji     138600.0            True
# 3              Trinitario         Indonesia     154687.5            True
# 4                 Criollo        Madagascar     103125.0           False
# ..                    ...               ...          ...             ...
# 790                 Blend             Other     110000.0           False
# 791                 Blend            Panama     126000.0           False
# 792  Forastero (Nacional)           Ecuador     112500.0           False
# 793   Criollo, Trinitario  Papua New Guinea     123750.0            True
# 794                 Blend           Bolivia     146250.0           False
#
# [795 rows x 10 columns]

# %%
dark_chocolates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795 entries, 0 to 794
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               795 non-null    object
#  1   Specific Bean Origin  795 non-null    object
#  2   Review Date           795 non-null    int64
#  3   Cocoa Percent         795 non-null    float64
#  4   Company Location      795 non-null    object
#  5   Rating                795 non-null    float64
#  6   Bean Type             795 non-null    object
#  7   Broad Bean Origin     794 non-null    object
#  8   price(100g)           795 non-null    float64
#  9   has_Trinitario        795 non-null    bool
# dtypes: bool(1), float64(3), int64(1), object(5)
# memory usage: 56.8+ KB

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت پنجم
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در مرحله‌ی آخر می‌خواهیم بدانیم در مجموع از فروش این شکلات‌های تلخ با قیمت‌هایی که مشخص کرده‌ایم چه‌قدر دریافت می‌کنیم. بنابراین مجموع قیمت شکلات‌های تلخ (ستون <code>price(100g)</code>) را محاسبه کرده و در متغیر <code>priceSum</code> ذخیره کنید.
# </font>
# </p>

# %%
priceSum = dark_chocolates['price(100g)'].sum()
priceSum
# Out:
# np.float64(96733662.5)

# %%
df.to_csv('/chocolate_price.csv', index=False)

# %%
from google.colab import files

# ذخیره موقت به یک فایل CSV داخل فضای Colab
#df.to_csv('my_dataset.csv', index=False)
df.to_csv('/chocolate_price.csv', index=False)

# دانلود فایل به سیستم لوکال
files.download('/chocolate_price.csv')

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zlib
import zipfile

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

df.to_csv('chocolate_price.csv', index = False)
dark_chocolates.to_csv('dark_chocolates.csv', index = True)

np.savez("answers.npz", has_Trinitario = has_Trinitario, priceSum = priceSum)
file_names = ["answers.npz", "project1_step2.ipynb", "chocolate_price.csv", "dark_chocolates.csv"]
compress(file_names)
# Out:
# File Paths:
# ['answers.npz', 'project1_step2.ipynb', 'chocolate_price.csv', 'dark_chocolates.csv']
