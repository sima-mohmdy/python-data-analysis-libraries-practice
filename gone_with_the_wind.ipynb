# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# بر باد رفته
# </font>
# </h1>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# مدتی‌ست که کاربران در بازی
# <i>FIFA</i>
#  دیگر نمی‌توانند با استراتژی سانتر و هد گل بزنند. برخی ادعا می‌کنند که دلیل این اتفاق، کاهش قد بازیکنان فوتبال است. در این تمرین با داشتن داده‌های بازی‌های
# <i>FIFA 11</i>
#   و
# <i>FIFA 21</i>،
#  این فرضیه را بررسی می‌کنیم.
# </font>
# </p>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/ML/DataMining')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت اول
# </font>
#
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در این تمرین، به چهار صفحه‌محور نیاز داریم. در سلول زیر یک شکل با ۴ صفحه‌محور (دو سطر و دو ستون) ایجاد کنید. طول و عرض شکل را برابر ۱۰ اینچ قرار دهید.
#
# <ul dir=rtl style="direction: rtl;text-align: justify;">
#   <li>
# عنوان شکل را <code>fifa11 vs fifa21</code> قرار دهید.
# </li>
#   <li>
# اندازه‌ی فونت عنوان شکل را برابر با <code>xx-large</code> قرار دهید.
# </li>
# </font>
# </p>

# %%
# TODO: create the figure and plots
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle('fifa11 vs fifa21', fontsize='xx-large')

plt.show()

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت دوم
# </font>
#
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در این مرحله داده‌های لازم برای رسم نمودار‌ها را ایجاد کنیم. برای این‌کار، داده‌های فیفا ۱۱ و فیفا ۲۱ را بخوانید و از هر مجموعه‌داده، دو ستون <code>weight</code> و <code>height</code> را در دیتافریمی جدید به نام <code>plot_df</code> بریزید.
# پس از ایجاد دیتافریم جدید، با تابع <code>head</code> بررسی کنید که دو سطر اول به شکل زیر باشد (نام ستون‌ها باید عیناً مانند شکل زیر باشد.).
# </font>
# </p>

# %% [markdown]
# <div style="line-height:200%;font-family:vazir;font-size:medium">
# <p style="direction: rtl;text-align: right;">
# <table align = center dir=ltr>
#
#
# <tr>
# <th>  </th>
# <th><font face="vazirmatn" size=3>weight2011</th>
# <th><font face="vazirmatn" size=3>weight2021</th>
# <th><font face="vazirmatn" size=3>height2011</th>
# <th><font face="vazirmatn" size=3>height2021</th>
#
# </tr>
#
# <tr>
# <td><font face="vazirmatn" size=3>0</td>
# <td><font face="vazirmatn" size=3>75.0</td>
# <td><font face="vazirmatn" size=3>68</td>
# <td><font face="vazirmatn" size=3>188.0</td>
# <td><font face="vazirmatn" size=3>184</td>
# </tr>
#
# <tr>
# <td>1</td>
# <td>69.0</td>
# <td>75</td>
# <td>172.0</td>
# <td>185</td>
# </tr>
#
#
# </table>
# </div</p>
# </div>

# %% [markdown]
# <div style="line-height:200%;font-family:vazir;font-size:medium">
# <p style="direction: rtl;text-align: justify;">
# <span style="color:purple"><b>دقت کنید که  </b></span>
# در
# <i> FIFA 11</i>
# تعداد بازیکنان کمتر از
# <i> FIFA 21</i>
#  می‌باشد و در نتیجه هنگام ایجاد دیتا فریم <code>plot_df</code>، مقدار بعضی از خانه‌ها خالی می‌ماند.
# <br>
#  <span style="color:green"><b>راهنمایی بزرگ:</b></span>
#   برای این بخش می‌توانید از دستور
#  <code>concat</code>
#  استفاده کنید.
# </p>
# </div>

# %%
fifa11 = pd.read_csv('/content/drive/MyDrive/ML/DataMining/بر باد رفته/fifa11.csv')
fifa11
# Out:
#            id          Fullname  current_rating  potential_rating  height  \
# 0        3721      Nenad Dzodic              72                75     188
# 1      192989    Fanol Perdedaj              60                78     172
# 2      199296   Kliment Taseski              52                68     180
# 3      150655  Gilles Yapi Yapo              73                82     171
# 4      157190      John Russell              55                63     174
# ...       ...               ...             ...               ...     ...
# 15015  187073      Seo Sang Min              61                69     175
# 15016  188386     Edouard Butin              61                75     180
# 15017  173634       Jamie Green              58                65     170
# 15018  182621     Daniel Gordon              63                72     194
# 15019  193030       Milan Lukac              65                72     197
#
#        weight preferred_foot  birth_date preferred_positions  work_rate  ...  \
# 0          75          Right  04/01/1977            CB-RB-SW        NaN  ...
# 1          69          Right  16/07/1991              CDM-CM        NaN  ...
# 2          75          Right  27/05/1991        CAM-ST-RW-CM        NaN  ...
# 3          63          Right  30/01/1982           CM-RM-CDM        NaN  ...
# 4          71          Right  18/05/1985            CM-RM-RW        NaN  ...
# ...       ...            ...         ...                 ...        ...  ...
# 15015      69          Right  25/07/1986              CAM-CF        NaN  ...
# 15016      76          Right  13/06/1988                  ST        NaN  ...
# 15017      67           Left  18/08/1989           LWB-LB-LM        NaN  ...
# 15018      83          Right  16/01/1985              CDM-CM        NaN  ...
# 15019      88          Right  04/10/1985                  GK        NaN  ...
#
#        long_shots  curve  fk_acc  penalties  volleys  gk_positioning  \
# 0              51     12      57         17        5              13
# 1              39     49      31         49        9               9
# 2              50     50      56         57       12              14
# 3              49     68      78         63        5               7
# 4              42     42      57         46        5               6
# ...           ...    ...     ...        ...      ...             ...
# 15015          54     61      44         52        7              13
# 15016          48     44      42         43        5               7
# 15017          46     34      23         26       10              13
# 15018          56     49      51         38       14              14
# 15019          15     21      13          5       76              61
#
#        gk_diving  gk_handling  gk_kicking  gk_reflexes
# 0              5           11         8.0          NaN
# 1             13           14        13.0          NaN
# 2             15           13         5.0          NaN
# 3             10           12        11.0          NaN
# 4              8           14        13.0          NaN
# ...          ...          ...         ...          ...
# 15015         15            7        11.0          NaN
# 15016         13           14         7.0          NaN
# 15017         12            7        10.0          NaN
# 15018         14           14        13.0          NaN
# 15019         62           61         NaN          NaN
#
# [15020 rows x 48 columns]

# %%
fifa21 = pd.read_csv('/content/drive/MyDrive/ML/DataMining/بر باد رفته/fifa21.csv')
fifa21
# Out:
#            id         Fullname  current_rating  potential_rating  height  \
# 0      255402   Mauricio Isais              58                74     184
# 1      234111   David Turnbull              69                82     185
# 2      192989   Fanol Përdedaj              64                64     173
# 3      241011   Saša Jovanović              66                66     176
# 4      220502  Mattia Zaccagni              75                80     177
# ...       ...              ...             ...               ...     ...
# 18997  258161          Peteiro              61                72     176
# 18998  242995      Joseph Mora              68                69     176
# 18999  257294   Shandon Hopeau              56                68     180
# 19000  237895  Vito van Crooij              67                71     177
# 19001  236787   Dominik Franke              59                72     184
#
#        weight preferred_foot  birth_date preferred_positions        work_rate  \
# 0          68          Right  09/04/2001                  RW  Medium / Medium
# 1          75          Right  10/07/1999              CM-CAM      High / High
# 2          70          Right  16/07/1991              CDM-CM    Medium / High
# 3          75           Left  15/12/1991            RM-LM-ST  Medium / Medium
# 4          63          Right  16/06/1995               CF-ST    High / Medium
# ...       ...            ...         ...                 ...              ...
# 18997      71          Right  26/05/1998                  CB  Medium / Medium
# 18998      60           Left  15/01/1993              LB-LWB  Medium / Medium
# 18999      73          Right  01/12/1998               RM-RW  Medium / Medium
# 19000      70          Right  29/01/1996               LW-RW       High / Low
# 19001      76           Left  05/10/1998               CB-LB  Medium / Medium
#
#        ...  long_shots  curve fk_acc  penalties  volleys  gk_positioning  \
# 0      ...          49     47     46         64       50              11
# 1      ...          72     67     70         75       54              15
# 2      ...          50     58     57         32       47              10
# 3      ...          49     55     47         66       48               5
# 4      ...          68     55     48         55       53               8
# ...    ...         ...    ...    ...        ...      ...             ...
# 18997  ...          31     34     37         43       31              14
# 18998  ...          42     50     39         44       39               6
# 18999  ...          44     38     32         54       42               6
# 19000  ...          69     69     66         62       62              14
# 19001  ...          35     45     44         39       31               9
#
#        gk_diving  gk_handling  gk_kicking  gk_reflexes
# 0             13           10          15            8
# 1              5            8          10            5
# 2             10           14          15           14
# 3              8           14          10           12
# 4             13           16          14            7
# ...          ...          ...         ...          ...
# 18997          7           15          13           11
# 18998         15           13          14           11
# 18999         15           14          10            7
# 19000         12           14           9           12
# 19001          8           10          14           13
#
# [19002 rows x 48 columns]

# %%
f11 = fifa11[['height', 'weight']].rename(columns={'height': 'height2011', 'weight': 'weight2011'})
f11
# Out:
#        height2011  weight2011
# 0             188          75
# 1             172          69
# 2             180          75
# 3             171          63
# 4             174          71
# ...           ...         ...
# 15015         175          69
# 15016         180          76
# 15017         170          67
# 15018         194          83
# 15019         197          88
#
# [15020 rows x 2 columns]

# %%
f21 = fifa21[['height', 'weight']].rename(columns={'height': 'height2021', 'weight': 'weight2021'})
f21
# Out:
#        height2021  weight2021
# 0             184          68
# 1             185          75
# 2             173          70
# 3             176          75
# 4             177          63
# ...           ...         ...
# 18997         176          71
# 18998         176          60
# 18999         180          73
# 19000         177          70
# 19001         184          76
#
# [19002 rows x 2 columns]

# %%
# TODO: create the new dataframe
plot_df = pd.concat([f11, f21], axis=1)
plot_df
# Out:
#        height2011  weight2011  height2021  weight2021
# 0           188.0        75.0         184          68
# 1           172.0        69.0         185          75
# 2           180.0        75.0         173          70
# 3           171.0        63.0         176          75
# 4           174.0        71.0         177          63
# ...           ...         ...         ...         ...
# 18997         NaN         NaN         176          71
# 18998         NaN         NaN         176          60
# 18999         NaN         NaN         180          73
# 19000         NaN         NaN         177          70
# 19001         NaN         NaN         184          76
#
# [19002 rows x 4 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت سوم
# </font>
#
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در صفحه‌محور اول، با استفاده از دو ستون <code>height2011</code> و <code>height2021</code> یک نمودار هیستوگرام بکشید. برای این‌کار دو ستون گفته‌شده را از دیتافریم <code>plot_df</code> را در یک دیتافریم جدید قرار دهید و با استفاده از واسط پانداز، نمودار هیستوگرام را بر روی صفحه‌محور اول رسم کنید. دقت کنید که فقط یک‌بار باید متد <code>plot</code> را فراخوانی کنید تا بازه‌ی سطل‌ها برای هر دو ستون، یک‌‌بار محاسبه شود.
# <br>
#
# <ul style="direction: rtl;text-align: justify;">
#     <li>متغیر <code>alpha</code> شفافیت میله‌ها را مشخص می‌کند. برای این‌که هر دو هیستوگرام قابل تفکیک باشند،‌ مقدار <code>alpha</code> را برابر <code>0.5</code> قرار دهید.
# </li>
#   <li>هیستوگرام در حالت عادی به مقادیر حساس است. یعنی چون تعداد بازیکنان
#   <i>FIFA 21</i>
#   بیشتر از
#   <i>FIFA 11</i>  است، هیستوگرام آن بالاتر از
#   <i>FIFA 11</i>
#    قرار می‌گیرد. برای حل این مشکل می‌توان هیستوگرام را نرمال کرد. در این حالت همه‌ی مقادیر بین <code>0</code> و <code>1</code> قرار می‌گیرند و دیگر و وابسته به تعداد‌ نمونه‌ها نیستند. برای فعال‌کردن این ویژگی، متغیر <code>density</code> را برابر <code>True</code> قرار دهید.
# </li>
#   <li>
#   عنوان نمودار را برابر <code>height histogram</code> قرار دهید.
# </li>
# </ul>
# </font>
# </p>

# %%
# TODO: create the figure and plots
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

plot_df_height = plot_df[['height2011', 'height2021']]

#plot_df_height.hist(plot_df_height.columns, density=True, alpha = 0.5)
plot_df_height.plot(kind='hist', ax=axes[0][0], alpha=0.5, density=True)

axes[0, 0].set_title('height histogram')

fig.suptitle('fifa11 vs fifa21', fontsize='xx-large')

plt.show()

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت چهارم
# </font>
#
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در صفحه‌محور دوم، تابع چگالی را رسم کنید. برای این کار دو ستون سوال قبل را  انتخاب کنید و در واسط پانداز نوع نمودار را بر روی <code>kde</code> قرار دهید. در این نمودار هم مقدار <code>alpha</code> را برابر
# <code>0.5</code>
#  قرار دهید تا تفکیک‌پذیری خطوط بهتر شود.
# <br>
#
# <ul style="direction: rtl;text-align: right;">
#   <li>
# در این نمودار هم مقدار <code>alpha</code> را برابر
# <code>0.5</code>
#  قرار دهید تا تفکیک‌پذیری خطوط بهتر شود.
# </li>
#
#   <li>
#   عنوان نمودار را برابر <code>height density plot</code> قرار دهید.
# </li>
#
# </ul>
# </font>
# </p>

# %%
# TODO: create the figure and plots
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

plot_df_height = plot_df[['height2011', 'height2021']]

plot_df_height.plot(kind='hist', ax=axes[0][0], alpha=0.5, density=True)
axes[0, 0].set_title('height histogram')

plot_df_height.plot(kind='kde', ax=axes[0][1], alpha=0.5)
axes[0, 1].set_title('height density plot')


fig.suptitle('fifa11 vs fifa21', fontsize='xx-large')

plt.show()

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت پنجم
# </font>
#
# </h2>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# مراحل طی‌شده در قسمت سوم و چهارم را این‌‌بار بر روی ستون‌های وزن انجام دهید. در صفحه‌محور سوم تابع هیستوگرام و در صفحه‌محور چهارم تابع چگالی وزن
# <i>FIFA 11</i>
#  و
#  <i>FIFA 21</i>
#   را رسم کنید.
# <br>
# مقدار آلفا را برابر
# <code>0.5</code>
#  قرار داده و عنوان نمودار‌ها را مانند مراحل قبل بنویسید و به جای <code>height</code>، عبارت <code>weight</code> را قرار دهید.
# </font>
# </p>

# %%
# TODO: create the figure and plots
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

plot_df_height = plot_df[['height2011', 'height2021']]


plot_df_height.plot(kind='hist', ax=axes[0][0], alpha=0.5, density=True)
axes[0, 0].set_title('height histogram')

plot_df_height.plot(kind='kde', ax=axes[0][1], alpha=0.5)
axes[0, 1].set_title('height density plot')


plot_df_weight = plot_df[['weight2011', 'weight2021']]


plot_df_weight.plot(kind='hist', ax=axes[1][0], alpha=0.5, density=True)
axes[1, 0].set_title('weight histogram')

plot_df_weight.plot(kind='kde', ax=axes[1][1], alpha=0.5)
axes[1, 1].set_title('weight density plot')


fig.suptitle('fifa11 vs fifa21', fontsize='xx-large')

plt.show()

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# خروجی نهایی باید به شکل زیر باشد.
#
# </font>
# </p>

# %% [markdown]
# <p style="text-align:center; background-color:white;"><img src="output.png" alt="Logo"></p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zlib
import zipfile
import joblib

joblib.dump(fig,"fig")
plot_df.to_csv("plot_df.csv")

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ["plot_df.csv", "fig", "gone_with_the_wind.ipynb"]
compress(file_names)
# Out:
# File Paths:
# ['plot_df.csv', 'fig', 'gone_with_the_wind.ipynb']
